# %%
city = ["Solboa", "Raris", "Lonpon", "Bodrid", "Serlin"]


temperatures = [
    {
        "city": "Solboa",
        "temperatures": [13, 14, 14, 12, 11, 15, 16, 15, 15, 14, 13, 12, 9]
    },
    {
        "city": "Raris",
        "temperatures": [10, 11, 12, 11, 23, 9, 7, 7, 8, 10, 11, 11, 8]
    },
    {
        "city": "Lonpon",
        "temperatures": [8, 8, 7, 8, 4, 5, 3, 3, 4, 7, 8, 9, 8]
    },
    {
        "city": "Bodrid",
        "temperatures": [12, 14, 114, 15, 14, 11, 10, 10, 1, 9, 9, 10, 8]
    },
    {
        "city": "Serlin",
        "temperatures": [283, 284, 285, 284, 286, 286, 283, 282, 281, 281, 280, 281, 282]
    },

]

# %%
def main():
    pass

if __name__ == '__main__':
    main()

# %%
for c in temperatures:
    print(c['city'])
    for t in c['temperatures']:
        print(t)
# Out:
# Solboa
# 13
# 14
# 14
# 12
# 11
# 15
# 16
# 15
# 15
# 14
# 13
# 12
# 9
# Raris
# 10
# 11
# 12
# 11
# 23
# 9
# 7
# 7
# 8
# 10
# 11
# 11
# 8
# Lonpon
# 8
# 8
# 7
# 8
# 4
# 5
# 3
# 3
# 4
# 7
# 8
# 9
# 8
# Bodrid
# 12
# 14
# 114
# 15
# 14
# 11
# 10
# 10
# 1
# 9
# 9
# 10
# 8
# Serlin
# 283
# 284
# 285
# 284
# 286
# 286
# 283
# 282
# 281
# 281
# 280
# 281
# 282

# %%
print(temperatures)
# Out:
# [{'city': 'Solboa', 'temperatures': [13, 14, 14, 12, 11, 15, 16, 15, 15, 14, 13, 12, 9]}, {'city': 'Raris', 'temperatures': [10, 11, 12, 11, 23, 9, 7, 7, 8, 10, 11, 11, 8]}, {'city': 'Lonpon', 'temperatures': [8, 8, 7, 8, 4, 5, 3, 3, 4, 7, 8, 9, 8]}, {'city': 'Bodrid', 'temperatures': [12, 14, 114, 15, 14, 11, 10, 10, 1, 9, 9, 10, 8]}, {'city': 'Serlin', 'temperatures': [283, 284, 285, 284, 286, 286, 283, 282, 281, 281, 280, 281, 282]}]

# %%
for city in temperatures:
    print(city['city'])
    avg_total = 0
    for c,t in enumerate(city['temperatures']):
        print("Day {day_number}: {temperature:.2f}".format(day_number=c,temperature=t))#{'day_number': c, 'temperature': t}
        avg_total += t
    #calculate the average
    print(len(city['temperatures']))
    avg = avg_total/len(city['temperatures'])
    print(avg)
    sdv=
# Out:
# Solboa
# Day 0: 13.00
# Day 1: 14.00
# Day 2: 14.00
# Day 3: 12.00
# Day 4: 11.00
# Day 5: 15.00
# Day 6: 16.00
# Day 7: 15.00
# Day 8: 15.00
# Day 9: 14.00
# Day 10: 13.00
# Day 11: 12.00
# Day 12: 9.00
# 13
# 13.307692307692308
# Raris
# Day 0: 10.00
# Day 1: 11.00
# Day 2: 12.00
# Day 3: 11.00
# Day 4: 23.00
# Day 5: 9.00
# Day 6: 7.00
# Day 7: 7.00
# Day 8: 8.00
# Day 9: 10.00
# Day 10: 11.00
# Day 11: 11.00
# Day 12: 8.00
# 13
# 10.615384615384615
# Lonpon
# Day 0: 8.00
# Day 1: 8.00
# Day 2: 7.00
# Day 3: 8.00
# Day 4: 4.00
# Day 5: 5.00
# Day 6: 3.00
# Day 7: 3.00
# Day 8: 4.00
# Day 9: 7.00
# Day 10: 8.00
# Day 11: 9.00
# Day 12: 8.00
# 13
# 6.3076923076923075
# Bodrid
# Day 0: 12.00
# Day 1: 14.00
# Day 2: 114.00
# Day 3: 15.00
# Day 4: 14.00
# Day 5: 11.00
# Day 6: 10.00
# Day 7: 10.00
# Day 8: 1.00
# Day 9: 9.00
# Day 10: 9.00
# Day 11: 10.00
# Day 12: 8.00
# 13
# 18.23076923076923
# Serlin
# Day 0: 283.00
# Day 1: 284.00
# Day 2: 285.00
# Day 3: 284.00
# Day 4: 286.00
# Day 5: 286.00
# Day 6: 283.00
# Day 7: 282.00
# Day 8: 281.00
# Day 9: 281.00
# Day 10: 280.00
# Day 11: 281.00
# Day 12: 282.00
# 13
# 282.9230769230769
